# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("simple_life_expectancy.csv")

# %%
df
# Out:
#                                 Country; Year  \
# 0                           Afghanistan; 2013
# 1                           Afghanistan; 2012
# 2                           Afghanistan; 2000
# 3                           Afghanistan; 1990
# 4                               Albania; 2013
# 5                               Albania; 2012
# 6                               Albania; 2000
# 7                               Albania; 1990
# 8                               Algeria; 2013
# 9                               Algeria; 2012
# 10                              Algeria; 2000
# 11                              Algeria; 1990
# 12                              Andorra; 2013
# 13                              Andorra; 2012
# 14                              Andorra; 2000
# 15                              Andorra; 1990
# 16                               Angola; 2013
# 17                               Angola; 2012
# 18                               Angola; 2000
# ...

# %%
df.columns
# Out:
# Index(['Country; Year', 'Life expectancy at birth (years); Both sexes',
#        'Life expectancy at birth (years); Female',
#        'Life expectancy at birth (years); Male',
#        'Life expectancy at age 60 (years); Both sexes',
#        'Life expectancy at age 60 (years); Female',
#        'Life expectancy at age 60 (years); Male',
#        'Healthy life expectancy (HALE) at birth (years); Both sexes',
#        'Healthy life expectancy (HALE) at birth (years); Female',
#        'Healthy life expectancy (HALE) at birth (years); Male'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 776 entries, 0 to 775
# Data columns (total 10 columns):
# Country; Year                                                  776 non-null object
# Life expectancy at birth (years); Both sexes                   776 non-null int64
# Life expectancy at birth (years); Female                       776 non-null int64
# Life expectancy at birth (years); Male                         776 non-null int64
# Life expectancy at age 60 (years); Both sexes                  776 non-null int64
# Life expectancy at age 60 (years); Female                      776 non-null int64
# Life expectancy at age 60 (years); Male                        776 non-null int64
# Healthy life expectancy (HALE) at birth (years); Both sexes    582 non-null object
# Healthy life expectancy (HALE) at birth (years); Female        582 non-null object
# Healthy life expectancy (HALE) at birth (years); Male          582 non-null object
# dtypes: int64(6), object(4)
# ...

# %%
df.ix[1:,3].max()
# Out:
# '87'

# %%
df2 = pd.read_csv("access_to_water.csv")

# %%
df2
# Out:
#                                          Country; Year  \
# 0                                    Afghanistan; 2015
# 1                                    Afghanistan; 2000
# 2                                        Albania; 2015
# 3                                        Albania; 2000
# 4                                        Albania; 1990
# 5                                        Algeria; 2015
# 6                                        Algeria; 2000
# 7                                        Algeria; 1990
# 8                                        Andorra; 2015
# 9                                        Andorra; 2000
# 10                                       Andorra; 1990
# 11                                        Angola; 2015
# 12                                        Angola; 2000
# 13                                        Angola; 1990
# 14                           Antigua and Barbuda; 2015
# 15                           Antigua and Barbuda; 2000
# ...

# %%
df2['Country'], df2['Year'] = zip(*df2['Country; Year'].apply(lambda x: x.split('; ', 1)))

# %%
len(df2['Country'].unique())
# Out:
# 192

# %%
df2
# Out:
#                                          Country; Year  \
# 0                                    Afghanistan; 2015
# 1                                    Afghanistan; 2000
# 2                                        Albania; 2015
# 3                                        Albania; 2000
# 4                                        Albania; 1990
# 5                                        Algeria; 2015
# 6                                        Algeria; 2000
# 7                                        Algeria; 1990
# 8                                        Andorra; 2015
# 9                                        Andorra; 2000
# 10                                       Andorra; 1990
# 11                                        Angola; 2015
# 12                                        Angola; 2000
# 13                                        Angola; 1990
# 14                           Antigua and Barbuda; 2015
# 15                           Antigua and Barbuda; 2000
# ...

# %%
df2[df2.Year == '2015'][]
# Out:
#                                          Country; Year  \
# 0                                    Afghanistan; 2015
# 2                                        Albania; 2015
# 5                                        Algeria; 2015
# 8                                        Andorra; 2015
# 11                                        Angola; 2015
# 14                           Antigua and Barbuda; 2015
# 17                                     Argentina; 2015
# 20                                       Armenia; 2015
# 23                                     Australia; 2015
# 26                                       Austria; 2015
# 29                                    Azerbaijan; 2015
# 32                                       Bahamas; 2015
# 34                                       Bahrain; 2015
# 37                                    Bangladesh; 2015
# 40                                      Barbados; 2015
# 43                                       Belarus; 2015
# ...
