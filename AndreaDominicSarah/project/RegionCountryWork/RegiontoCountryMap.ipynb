# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as pyplot

# %% [markdown]
# In this notebook we are building a list of countries within each WHO defined region, using country lists provided by the WHO webside (by region). For the Africa region only, the data was provided in a table. In this case, we used the read_html pandas function. For all other regions, the tables were not presented in a Table format. In these cases, we saved the html source behind the page the tables were presented (URLs provided) using the "view source" command within Chrome. From here, we imported the html file as text, sliced for the rows that contained the Country data, and the split those rows in order have only the Country names.

# %% [markdown]
# # Africa

# %%
africa_raw = pd.read_html('http://www.afro.who.int/en/countries.html')[0][1:]

# %%
africa_raw
# Out:
#                                     0                                      1  \
# 1                    Algeria (French)                 Cote d'Ivoire (French)
# 2                 Angola (Portuguese)  Democratic Republic of Congo (French)
# 3                      Benin (French)             Equatorial Guinea (French)
# 4                            Botswana                               Ethiopia
# 5               Burkina Faso (French)                                Eritrea
# 6                    Burundi (French)                         Gabon (French)
# 7                   Cameroon (French)                                 Gambia
# 8             Cabo Verde (Portuguese)                                  Ghana
# 9   Central African Republic (French)                        Guinea (French)
# 10                      Chad (French)             Guinea-Bissau (Portuguese)
# 11                   Comoros (French)                                  Kenya
# 12                     Congo (French)                                Lesotho
#
#                                     2                            3
# 1                             Liberia             Senegal (French)
# 2                 Madagascar (French)                   Seychelles
# 3                              Malawi                 Sierra Leone
# 4                       Mali (French)                 South Africa
# 5                 Mauritania (French)                  South Sudan
# 6                           Mauritius                    Swaziland
# 7   Mozambique (Portuguese) (English)                Togo (French)
# 8                             Namibia                       Uganda
# 9                      Niger (French)  United Republic of Tanzania
# 10                            Nigeria                       Zambia
# 11                             Rwanda                     Zimbabwe
# 12     Sao Tome and Principe (French)                          NaN

# %%
africa = pd.melt(africa_raw)
africa['Region'] = "Africa"
africa['Country'] = africa['value']
del africa['variable']
del africa['value']
africa
# Out:
#     Region                                Country
# 0   Africa                       Algeria (French)
# 1   Africa                    Angola (Portuguese)
# 2   Africa                         Benin (French)
# 3   Africa                               Botswana
# 4   Africa                  Burkina Faso (French)
# 5   Africa                       Burundi (French)
# 6   Africa                      Cameroon (French)
# 7   Africa                Cabo Verde (Portuguese)
# 8   Africa      Central African Republic (French)
# 9   Africa                          Chad (French)
# 10  Africa                       Comoros (French)
# 11  Africa                         Congo (French)
# 12  Africa                 Cote d'Ivoire (French)
# 13  Africa  Democratic Republic of Congo (French)
# 14  Africa             Equatorial Guinea (French)
# 15  Africa                               Ethiopia
# 16  Africa                                Eritrea
# 17  Africa                         Gabon (French)
# 18  Africa                                 Gambia
# 19  Africa                                  Ghana
# 20  Africa                        Guinea (French)
# 21  Africa             Guinea-Bissau (Portuguese)
# 22  Africa                                  Kenya
# 23  Africa                                Lesotho
# 24  Africa                                Liberia
# 25  Africa                    Madagascar (French)
# 26  Africa                                 Malawi
# 27  Africa                          Mali (French)
# 28  Africa                    Mauritania (French)
# 29  Africa                              Mauritius
# 30  Africa      Mozambique (Portuguese) (English)
# 31  Africa                                Namibia
# 32  Africa                         Niger (French)
# 33  Africa                                Nigeria
# 34  Africa                                 Rwanda
# 35  Africa         Sao Tome and Principe (French)
# 36  Africa                       Senegal (French)
# 37  Africa                             Seychelles
# 38  Africa                           Sierra Leone
# 39  Africa                           South Africa
# 40  Africa                            South Sudan
# 41  Africa                              Swaziland
# 42  Africa                          Togo (French)
# 43  Africa                                 Uganda
# 44  Africa            United Republic of Tanzania
# 45  Africa                                 Zambia
# 46  Africa                               Zimbabwe
# 47  Africa                                    NaN

# %%
#remove NaN value and then drop the language references
africa = africa.drop([47])
africa['Country'] = africa['Country'].apply(lambda x: x.split('(')[0])
africa.head()
# Out:
#    Region        Country
# 0  Africa       Algeria
# 1  Africa        Angola
# 2  Africa         Benin
# 3  Africa       Botswana
# 4  Africa  Burkina Faso

# %% [markdown]
# # Europe

# %%
# captures this file by doing a view source of html page, and saving as an html file
#open the file
#original source page: http://www.euro.who.int/en/countries
euro_raw_open = open('Region-Country-Sources/Euro.html', 'r', encoding='ISO-8859-2')

# %%
#use readlines to return a list of lines
euro_raw = euro_raw_open.readlines()
len(euro_raw)
#determined specific lines of HTML by looking at viewsource
euro_raw = euro_raw[243:304]

# %%
# now we need to extract the Country from each list
# 1. only look at lines with a country in them - ie have a tag
# 2. split the line twice: first looks for anything after a '">' the sencond looks for anything before '</a>'
eu = [x.split('">')[1].split("</a>")[0] for x in euro_raw if '">' in x]
eu
# Out:
# ['Albania',
#  'Andorra',
#  'Armenia',
#  'Austria',
#  'Azerbaijan',
#  'Belarus',
#  'Belgium',
#  'Bosnia and Herzegovina',
#  'Bulgaria',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Kazakhstan',
#  'Kyrgyzstan',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Malta',
#  'Monaco',
#  'Montenegro',
#  'Netherlands',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Republic of Moldova',
#  'Romania',
#  'Russian Federation',
#  'San Marino',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Tajikistan',
#  'The former Yugoslav Republic of Macedonia',
#  'Turkey',
#  'Turkmenistan',
#  'Ukraine',
#  'United Kingdom of Great Britain and Northern Ireland',
#  'Uzbekistan']

# %%
europe = pd.DataFrame({'Region': 'Europe', 'Country': eu})
europe.head()
# Out:
#       Country  Region
# 0     Albania  Europe
# 1     Andorra  Europe
# 2     Armenia  Europe
# 3     Austria  Europe
# 4  Azerbaijan  Europe

# %% [markdown]
# # Region of Americas

# %%
# Same process as Europe - use viewsource
# captures this file by doing a view source of html page, and saving as an html file
#open the file
#original source page: http://www.paho.org/hq/index.php?option=com_wrapper&view=wrapper&Itemid=2005&lang=en
americas_raw_open = open('Region-Country-Sources/Americas.html', 'r', encoding='ISO-8859-2')

# %%
#use readlines to return a list of lines
americas_raw = americas_raw_open.readlines()
#determined specific lines of HTML by looking at viewsource
americas_raw = americas_raw[29:166]
len(americas_raw)
# Out:
# 137

# %%
am = [x.split('alt="')[1].split('" style="')[0] for x in americas_raw if 'alt="' in x]
am
# Out:
# ['Antigua and Barbuda',
#  'Argentina',
#  'Aruba',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'Bermuda',
#  'Bolivarian Republic of Venezuela',
#  'Bolivia',
#  'Brazil',
#  'British Virgin Islands (UK)',
#  'Canada',
#  'Cayman Islands',
#  'Chile',
#  'Colombia',
#  'Costa Rica',
#  'Cuba',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'El Salvador',
#  'French Guiana',
#  'Grenada',
#  'Guadeloupe',
#  'Guatemala',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Jamaica',
#  'Martinique',
#  'Mexico',
#  'Montserrat',
#  'Netherland Antilles',
#  'Nicaragua',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Puerto Rico',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Vincent and the Grenadines',
#  'Suriname',
#  'Trinidad and Tobago',
#  'Turks and Caicos',
#  'United States of America',
#  'Uruguay']

# %%
americas = pd.DataFrame({'Region': 'Americas', 'Country': am})
americas.head()
# Out:
#                Country    Region
# 0  Antigua and Barbuda  Americas
# 1            Argentina  Americas
# 2                Aruba  Americas
# 3              Bahamas  Americas
# 4             Barbados  Americas

# %% [markdown]
# # Southeast Asia

# %%
# again, information is not organized into a table on web page, so using viewsource as text file to read
# original source page: http://www.searo.who.int/countries/en/
seasia_raw_open = open('Region-Country-Sources/SEAsia.html', 'r', encoding='ISO-8859-2')

# %%
# use readlines to return a list of lines
seasia_raw = seasia_raw_open.readlines()
# determined specific lines of HTML by looking at viewsource
seasia_raw = seasia_raw[287:346]
seasia_raw
# Out:
# ['<a href="/bangladesh" class="" >Bangladesh</a> \n',
#  '\t\t\t\t</li>\n',
#  '\t\t\t\t<li>\n',
#  '<a href="/bhutan" class="" >Bhutan</a> \n',
#  '\t\t\t\t</li>\n',
#  '\t\t\t\t<li>\n',
#  '<a href="/dprkorea" class="" >Democratic Peopleâ\x80\x99s Republic of Korea</a> \n',
#  '\t\t\t\t</li>\n',
#  '\t\t\t\t<li>\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\t<a  href="/entity/india/en/index.html">India</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t\t\t\t<li>\n',
#  '<a href="/indonesia" class="" >Indonesia</a> \n',
#  '\t\t\t\t</li>\n',
#  '\t\t\t\t<li>\n',
#  '<a href="/maldives" class="" >Maldives</a> \n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '</div>\n',
#  '<!-- begin: box -->\n',
#  '\n',
#  '</div>\n',
#  '<!-- end subcol_1-1_1 -->\n',
#  '\n',
#  '<!-- start subcol_1-1_2 -->\n',
#  '<div class="subcol_1-1_2">\n',
#  '\n',
#  '<!-- begin: box -->\n',
#  '<div class="box">\n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '<a href="/myanmar" class="" >Myanmar</a> \n',
#  '\t\t\t\t</li>\n',
#  '\t\t\t\t<li>\n',
#  '<a href="/entity/nepal" class="" >Nepal</a> \n',
#  '\t\t\t\t</li>\n',
#  '\t\t\t\t<li>\n',
#  '<a href="/srilanka" class="" >Sri Lanka </a> \n',
#  '\t\t\t\t</li>\n',
#  '\t\t\t\t<li>\n',
#  '<a href="/thailand" class="" >Thailand</a> \n',
#  '\t\t\t\t</li>\n',
#  '\t\t\t\t<li>\n',
#  '<a href="/timorleste" class="" >Timor-Leste</a> \n']

# %%
sea = []
for x in seasia_raw:
    if '</a>' in x:
        if 'class=""' in x:
            sea.append(x.split('class="" >')[1].split('</a>')[0])
        else:
            sea.append(x.split('html">')[1].split('</a>')[0])
sea
# Out:
# ['Bangladesh',
#  'Bhutan',
#  'Democratic Peopleâ\x80\x99s Republic of Korea',
#  'India',
#  'Indonesia',
#  'Maldives',
#  'Myanmar',
#  'Nepal',
#  'Sri Lanka ',
#  'Thailand',
#  'Timor-Leste']

# %%
seasia = pd.DataFrame({'Region': 'Southeast Asia', 'Country': sea})
seasia
# Out:
#                                     Country          Region
# 0                                Bangladesh  Southeast Asia
# 1                                    Bhutan  Southeast Asia
# 2   Democratic Peopleâs Republic of Korea  Southeast Asia
# 3                                     India  Southeast Asia
# 4                                 Indonesia  Southeast Asia
# 5                                  Maldives  Southeast Asia
# 6                                   Myanmar  Southeast Asia
# 7                                     Nepal  Southeast Asia
# 8                                Sri Lanka   Southeast Asia
# 9                                  Thailand  Southeast Asia
# 10                              Timor-Leste  Southeast Asia

# %% [markdown]
# # Eastern Mediteranean

# %%
# original source: http://www.emro.who.int/countries.html
eastern_med_raw_open = open('Region-Country-Sources/EasternMed.html', 'r', encoding='ISO-8859-2')

# %%
# use readlines to return a list of lines
emed_raw = eastern_med_raw_open.readlines()
# determined specific lines of HTML by looking at viewsource
emed_raw = emed_raw[183:223]
emed_raw
# Out:
# ['<p><a href="/countries/afg/index.html">Afghanistan</a></p>\n',
#  '<h3><a name="B"></a>B</h3>\n',
#  '<p><a href="/countries/bah/index.html">Bahrain</a></p>\n',
#  '<h3><a name="D"></a>D</h3>\n',
#  '<p><a href="/countries/dji/index.html">Djibouti</a></p>\n',
#  '<h3><a name="E"></a>E</h3>\n',
#  '<p><a href="/countries/egy/index.html">Egypt</a></p>\n',
#  '<h3><a name="I"></a>I</h3>\n',
#  '<p><a href="/countries/irn/index.html">Iran, Islamic Republic of</a></p>\n',
#  '<p><a href="/countries/irq/index.html">Iraq</a></p>\n',
#  '<h3><a name="J"></a>J</h3>\n',
#  '<p><a href="/countries/jor/index.html">Jordan</a></p>\n',
#  '<h3><a name="K"></a>K</h3>\n',
#  '<p><a href="/countries/kwt/index.html">Kuwait</a></p>\n',
#  '<h3><a name="L"></a>L</h3>\n',
#  '<p><a href="/countries/lbn/index.html">Lebanon</a></p>\n',
#  '<p><a href="/countries/lby/index.html">Libya</a></p>\n',
#  '<h3><a name="M"></a>M</h3>\n',
#  '<p><a href="/fr/countries/mor/index.html">Morocco</a></p>\n',
#  '</div>\n',
#  '<div class="topicsright">\n',
#  '<h3><a name="O"></a>O</h3>\n',
#  '<p><a href="/countries/pse/index.html">Occupied Palestinian territory</a></p>\n',
#  '<p><a href="/countries/omn/index.html">Oman</a></p>\n',
#  '<h3><a name="P"></a>P</h3>\n',
#  '<p><a href="/countries/pak/index.html">Pakistan</a></p>\n',
#  '<p><a href="/countries/pse/index.html">Palestine, see Occupied Palestinian territory</a></p>\n',
#  '<h3><a name="Q"></a>Q</h3>\n',
#  '<p><a href="/countries/qat/index.html">Qatar</a></p>\n',
#  '<h3><a name="S"></a>S</h3>\n',
#  '<p><a href="/countries/sau/index.html">Saudi Arabia</a></p>\n',
#  '<p><a href="/countries/som/index.html">Somalia</a></p>\n',
#  '<p><a href="/countries/sdn/index.html" style="background-color: #ffffff;">Sudan</a></p>\n',
#  '<p><a href="/countries/syr/index.html">Syrian Arab Republic</a></p>\n',
#  '<h3><a name="T"></a>T</h3>\n',
#  '<p><a href="/fr/countries/tun/index.html">Tunisia</a></p>\n',
#  '<h3><a name="U"></a>U</h3>\n',
#  '<p><a href="/countries/are/index.html">United Arab Emirates</a></p>\n',
#  '<h3><a name="Y"></a>Y</h3>\n',
#  '<p><a href="/countries/yem/index.html">Yemen</a></p>\n']

# %%
em = []
for x in emed_raw:
    if '</a>' in x:
        if 'html">' in x:
            em.append(x.split('html">')[1].split('</a>')[0])
        elif '#ffffff;">' in x:
            em.append(x.split('fff;">')[1].split('</a>')[0])
em
# Out:
# ['Afghanistan',
#  'Bahrain',
#  'Djibouti',
#  'Egypt',
#  'Iran, Islamic Republic of',
#  'Iraq',
#  'Jordan',
#  'Kuwait',
#  'Lebanon',
#  'Libya',
#  'Morocco',
#  'Occupied Palestinian territory',
#  'Oman',
#  'Pakistan',
#  'Palestine, see Occupied Palestinian territory',
#  'Qatar',
#  'Saudi Arabia',
#  'Somalia',
#  'Sudan',
#  'Syrian Arab Republic',
#  'Tunisia',
#  'United Arab Emirates',
#  'Yemen']

# %%
eastern_med = pd.DataFrame({'Region': 'Eastern Mediterranean', 'Country': em})
eastern_med
# Out:
#                                           Country                 Region
# 0                                     Afghanistan  Eastern Mediterranean
# 1                                         Bahrain  Eastern Mediterranean
# 2                                        Djibouti  Eastern Mediterranean
# 3                                           Egypt  Eastern Mediterranean
# 4                       Iran, Islamic Republic of  Eastern Mediterranean
# 5                                            Iraq  Eastern Mediterranean
# 6                                          Jordan  Eastern Mediterranean
# 7                                          Kuwait  Eastern Mediterranean
# 8                                         Lebanon  Eastern Mediterranean
# 9                                           Libya  Eastern Mediterranean
# 10                                        Morocco  Eastern Mediterranean
# 11                 Occupied Palestinian territory  Eastern Mediterranean
# 12                                           Oman  Eastern Mediterranean
# 13                                       Pakistan  Eastern Mediterranean
# 14  Palestine, see Occupied Palestinian territory  Eastern Mediterranean
# 15                                          Qatar  Eastern Mediterranean
# 16                                   Saudi Arabia  Eastern Mediterranean
# 17                                        Somalia  Eastern Mediterranean
# 18                                          Sudan  Eastern Mediterranean
# 19                           Syrian Arab Republic  Eastern Mediterranean
# 20                                        Tunisia  Eastern Mediterranean
# 21                           United Arab Emirates  Eastern Mediterranean
# 22                                          Yemen  Eastern Mediterranean

# %% [markdown]
# # Western Pacific

# %%
# original source: http://www.wpro.who.int/countries/en/
pacific_raw_open = open('Region-Country-Sources/Pacific.html', 'r', encoding='ISO-8859-2')

# %%
# use readlines to return a list of lines
pacific_raw = pacific_raw_open.readlines()
# determined specific lines of HTML by looking at viewsource
pacific_raw= pacific_raw[327:1059]
pacific_raw
# Out:
# ['\t<a  href="/countries/asm/en/index.html">American Samoa</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_aus_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/aus/en/index.html">Australia</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_bru_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/brn/en/index.html">Brunei Darussalam</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_cam_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/khm/en/index.html">Cambodia</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_chn_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/chn/en/index.html">China</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_cok_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/cok/en/index.html">Cook Islands</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_fij_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/fji/en/index.html">Fiji</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_frp_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/pyf/en/index.html">French Polynesia (France)</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_gum_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/gum/en/index.html">Guam (USA)</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_hok_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/hkg/en/index.html">Hong Kong (China)</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_jpn_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/jpn/en/index.html">Japan</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_kir_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/kir/en/index.html">Kiribati</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_lao_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/lao/en/index.html">Lao People\'s Democratic Republic</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_mac_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/mac/en/index.html">Macao (China)</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_maa_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/mys/en/index.html">Malaysia</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_msi_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/mhl/en/index.html">Marshall Islands</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_mic_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/fsm/en/index.html">Micronesia, Federated States of</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_mog_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/mng/en/index.html">Mongolia</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_nru_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/nru/en/index.html">Nauru</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '</div>\n',
#  '<!-- begin: box -->\n',
#  '\n',
#  '</div>\n',
#  '<!-- end subcol_1-1_1 -->\n',
#  '\n',
#  '<!-- start subcol_1-1_2 -->\n',
#  '<div class="subcol_1-1_2">\n',
#  '\n',
#  '<!-- begin: box -->\n',
#  '<div class="box">\n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_nec_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/ncl/en/index.html">New Caledonia (France)</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_nez_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/nzl/en/index.html">New Zealand</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_niu_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/niu/en/index.html">Niue</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_nmi_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/mnp/en/index.html">Northern Mariana Islands, Commonwealth of the</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_bla_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/plw/en/index.html">Palau</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_png_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/png/en/index.html">Papua New Guinea</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_phl_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/phl/en/index.html">Philippines</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_pcn_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/pcn/en/index.html">Pitcairn Islands (UK)</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_kor_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/kor/en/index.html">Republic of Korea</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_sma_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/wsm/en/index.html">Samoa</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_sin_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/sgp/en/index.html">Singapore</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_sol_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/slb/en/index.html">Solomon Islands</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_tok_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/tkl/en/index.html">Tokelau* (New Zealand)</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_ton_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/ton/en/index.html">Tonga</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_tuv_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/tuv/en/index.html">Tuvalu</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_van_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/vut/en/index.html">Vanuatu</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_vtn_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/vnm/en/index.html">Viet Nam</a>\n',
#  '\t\t\t\t</li>\n',
#  '\t</ul>\n',
#  '\n',
#  '\t\n',
#  '\t<div class="clear"> </div>\n',
#  '</div>\n',
#  '<!-- end: teaser -->\n',
#  '\n',
#  ' \n',
#  '<!-- start: teaser -->\n',
#  '<div class="teaser">\n',
#  '\t\n',
#  '   \n',
#  '<div  class="image_left"  style="width:24px">\n',
#  '<img src="/countries/flag_waf_sm.gif" alt="" width="24" height="16" />\n',
#  '</div>\n',
#  ' \n',
#  '      <ul class="list">\n',
#  '\t\t\t\t<li>\n',
#  '\t<a  href="/countries/wlf/en/index.html">Wallis and Futuna</a>\n']

# %%
wp = [x.split('html">')[1].split('</a>')[0] for x in pacific_raw if '</a>' in x]
wp
# Out:
# ['American Samoa',
#  'Australia',
#  'Brunei Darussalam',
#  'Cambodia',
#  'China',
#  'Cook Islands',
#  'Fiji',
#  'French Polynesia (France)',
#  'Guam (USA)',
#  'Hong Kong (China)',
#  'Japan',
#  'Kiribati',
#  "Lao People's Democratic Republic",
#  'Macao (China)',
#  'Malaysia',
#  'Marshall Islands',
#  'Micronesia, Federated States of',
#  'Mongolia',
#  'Nauru',
#  'New Caledonia (France)',
#  'New Zealand',
#  'Niue',
#  'Northern Mariana Islands, Commonwealth of the',
#  'Palau',
#  'Papua New Guinea',
#  'Philippines',
#  'Pitcairn Islands (UK)',
#  'Republic of Korea',
#  'Samoa',
#  'Singapore',
#  'Solomon Islands',
#  'Tokelau* (New Zealand)',
#  'Tonga',
#  'Tuvalu',
#  'Vanuatu',
#  'Viet Nam',
#  'Wallis and Futuna']

# %%
pacific = pd.DataFrame({'Region': 'Western Pacific', 'Country': wp})
pacific
# Out:
#                                           Country           Region
# 0                                  American Samoa  Western Pacific
# 1                                       Australia  Western Pacific
# 2                               Brunei Darussalam  Western Pacific
# 3                                        Cambodia  Western Pacific
# 4                                           China  Western Pacific
# 5                                    Cook Islands  Western Pacific
# 6                                            Fiji  Western Pacific
# 7                       French Polynesia (France)  Western Pacific
# 8                                      Guam (USA)  Western Pacific
# 9                               Hong Kong (China)  Western Pacific
# 10                                          Japan  Western Pacific
# 11                                       Kiribati  Western Pacific
# 12               Lao People's Democratic Republic  Western Pacific
# 13                                  Macao (China)  Western Pacific
# 14                                       Malaysia  Western Pacific
# 15                               Marshall Islands  Western Pacific
# 16                Micronesia, Federated States of  Western Pacific
# 17                                       Mongolia  Western Pacific
# 18                                          Nauru  Western Pacific
# 19                         New Caledonia (France)  Western Pacific
# 20                                    New Zealand  Western Pacific
# 21                                           Niue  Western Pacific
# 22  Northern Mariana Islands, Commonwealth of the  Western Pacific
# 23                                          Palau  Western Pacific
# 24                               Papua New Guinea  Western Pacific
# 25                                    Philippines  Western Pacific
# 26                          Pitcairn Islands (UK)  Western Pacific
# 27                              Republic of Korea  Western Pacific
# 28                                          Samoa  Western Pacific
# 29                                      Singapore  Western Pacific
# 30                                Solomon Islands  Western Pacific
# 31                         Tokelau* (New Zealand)  Western Pacific
# 32                                          Tonga  Western Pacific
# 33                                         Tuvalu  Western Pacific
# 34                                        Vanuatu  Western Pacific
# 35                                       Viet Nam  Western Pacific
# 36                              Wallis and Futuna  Western Pacific

# %%
# Merge all dataframes together

who_regions = [africa, europe, americas, seasia, eastern_med, pacific]

rc_map = pd.concat(who_regions)

rc_map
# Out:
#                                           Country           Region
# 0                                        Algeria            Africa
# 1                                         Angola            Africa
# 2                                          Benin            Africa
# 3                                        Botswana           Africa
# 4                                   Burkina Faso            Africa
# 5                                        Burundi            Africa
# 6                                       Cameroon            Africa
# 7                                     Cabo Verde            Africa
# 8                       Central African Republic            Africa
# 9                                           Chad            Africa
# 10                                       Comoros            Africa
# 11                                         Congo            Africa
# 12                                 Cote d'Ivoire            Africa
# 13                  Democratic Republic of Congo            Africa
# 14                             Equatorial Guinea            Africa
# 15                                       Ethiopia           Africa
# 16                                        Eritrea           Africa
# 17                                         Gabon            Africa
# 18                                         Gambia           Africa
# 19                                          Ghana           Africa
# 20                                        Guinea            Africa
# 21                                 Guinea-Bissau            Africa
# 22                                          Kenya           Africa
# 23                                        Lesotho           Africa
# 24                                        Liberia           Africa
# 25                                    Madagascar            Africa
# 26                                         Malawi           Africa
# 27                                          Mali            Africa
# 28                                    Mauritania            Africa
# 29                                      Mauritius           Africa
# ..                                            ...              ...
# 7                       French Polynesia (France)  Western Pacific
# 8                                      Guam (USA)  Western Pacific
# 9                               Hong Kong (China)  Western Pacific
# 10                                          Japan  Western Pacific
# 11                                       Kiribati  Western Pacific
# 12               Lao People's Democratic Republic  Western Pacific
# 13                                  Macao (China)  Western Pacific
# 14                                       Malaysia  Western Pacific
# 15                               Marshall Islands  Western Pacific
# 16                Micronesia, Federated States of  Western Pacific
# 17                                       Mongolia  Western Pacific
# 18                                          Nauru  Western Pacific
# 19                         New Caledonia (France)  Western Pacific
# 20                                    New Zealand  Western Pacific
# 21                                           Niue  Western Pacific
# 22  Northern Mariana Islands, Commonwealth of the  Western Pacific
# 23                                          Palau  Western Pacific
# 24                               Papua New Guinea  Western Pacific
# 25                                    Philippines  Western Pacific
# 26                          Pitcairn Islands (UK)  Western Pacific
# 27                              Republic of Korea  Western Pacific
# 28                                          Samoa  Western Pacific
# 29                                      Singapore  Western Pacific
# 30                                Solomon Islands  Western Pacific
# 31                         Tokelau* (New Zealand)  Western Pacific
# 32                                          Tonga  Western Pacific
# 33                                         Tuvalu  Western Pacific
# 34                                        Vanuatu  Western Pacific
# 35                                       Viet Nam  Western Pacific
# 36                              Wallis and Futuna  Western Pacific
#
# [217 rows x 2 columns]

# %%
rc_map['Region'].value_counts()
# Out:
# Europe                   53
# Africa                   47
# Americas                 46
# Western Pacific          37
# Eastern Mediterranean    23
# Southeast Asia           11
# Name: Region, dtype: int64

# %% [markdown]
# # Export file for use in main lab notebook

# %%
rc_map.to_csv('RegionCountryMap.csv')
